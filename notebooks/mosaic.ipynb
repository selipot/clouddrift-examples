# %% [markdown]
# Code to aggregate the MOSAiC drifter data into a ragged array
# https://arcticdata.io/catalog/view/doi:10.18739/A2KP7TS83

# %%
import xarray as xr
import clouddrift as cd
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
file1 = 'https://arcticdata.io/metacat/d1/mn/v2/object/urn%3Auuid%3A0021bc7f-e6cd-43e2-8525-87f07151363e'
ds = pd.read_csv(file1).to_xarray()
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (index: 5145)
# Coordinates:
#   * index      (index) int64 0 1 2 3 4 5 6 ... 5139 5140 5141 5142 5143 5144
# Data variables:
#     latitude   (index) float64 88.43 88.43 88.44 88.44 ... 85.93 85.93 85.92
#     longitude  (index) float64 117.6 117.6 117.7 117.7 ... -28.45 -28.44 -28.44
#     datetime   (index) object '2020-09-02 09:00:26' ... '2021-03-09 20:00:25'

# %%
plt.plot(ds.datetime,ds.latitude)

# %%
plt.plot(ds.longitude,ds.latitude)
